# %%
import soccerdata as sd
import pandas as pd
from sklearn.preprocessing import StandardScaler
# Out:
# [03/23/25 18:02:43] INFO     No custom team name replacements found. You can configure these in       ]8;id=384769;file://c:\Users\luizf\AppData\Local\Programs\Python\Python312\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=647391;file://c:\Users\luizf\AppData\Local\Programs\Python\Python312\Lib\site-packages\soccerdata\_config.py#91\91]8;;\
#                              C:\Users\luizf\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=984106;file://c:\Users\luizf\AppData\Local\Programs\Python\Python312\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=982292;file://c:\Users\luizf\AppData\Local\Programs\Python\Python312\Lib\site-packages\soccerdata\_config.py#200\200]8;;\
#                              C:\Users\luizf\soccerdata\config\league_dict.json.

# %%
csvnome = "ENG-Premier League_2024_TEAMS.csv"
df = pd.read_csv(csvnome)

# %%
print(list(df.columns))
# Out:
# ['Unnamed: 0', 'league_', 'season_', 'team_', 'players_used_', '90s_', 'Standard_Gls', 'Standard_Sh', 'Standard_SoT', 'Standard_SoT%', 'Standard_Sh/90', 'Standard_SoT/90', 'Standard_G/Sh', 'Standard_G/SoT', 'Standard_Dist', 'Standard_FK', 'Standard_PK', 'Standard_PKatt', 'Expected_xG', 'Expected_npxG', 'Expected_npxG/Sh', 'Expected_G-xG', 'Expected_np:G-xG', 'url_', 'Total_Cmp', 'Total_Att', 'Total_Cmp%', 'Total_TotDist', 'Total_PrgDist', 'Short_Cmp', 'Short_Att', 'Short_Cmp%', 'Medium_Cmp', 'Medium_Att', 'Medium_Cmp%', 'Long_Cmp', 'Long_Att', 'Long_Cmp%', 'Ast_', 'xAG_', 'Expected_xA', 'Expected_A-xAG', 'KP_', '1/3_', 'PPA_', 'CrsPA_', 'PrgP_', 'Att_', 'Pass Types_Live', 'Pass Types_Dead', 'Pass Types_FK', 'Pass Types_TB', 'Pass Types_Sw', 'Pass Types_Crs', 'Pass Types_TI', 'Pass Types_CK', 'Corner Kicks_In', 'Corner Kicks_Out', 'Corner Kicks_Str', 'Outcomes_Cmp', 'Outcomes_Off', 'Outcomes_Blocks', 'SCA_SCA', 'SCA_SCA90', 'SCA Types_PassLive', 'SCA Types_PassDead', 'SCA Types_TO', 'SCA Types_Sh', 'SCA Types_Fld', 'SCA Types_Def', 'GCA_GCA', 'GCA_GCA90', 'GCA Types_PassLive', 'GCA Types_PassDead', 'GCA Types_TO', 'GCA Types_Sh', 'GCA Types_Fld', 'GCA Types_Def', 'Tackles_Tkl', 'Tackles_TklW', 'Tackles_Def 3rd', 'Tackles_Mid 3rd', 'Tackles_Att 3rd', 'Challenges_Tkl', 'Challenges_Att', 'Challenges_Tkl%', 'Challenges_Lost', 'Blocks_Blocks', 'Blocks_Sh', 'Blocks_Pass', 'Int_', 'Tkl+Int_', 'Clr_', 'Err_', 'Poss_', 'Touches_Touches', 'Touches_Def Pen', 'Touches_Def 3rd', 'Touches_Mid 3rd', 'Touches_Att 3rd', 'Touches_Att Pen', 'Touches_Live', 'Take-Ons_Att', 'Take-Ons_Succ', 'Take-Ons_Succ%', 'Take-Ons_Tkld', 'Take-Ons_Tkld%', 'Carries_Carries', 'Carries_TotDist', 'Carries_PrgDist', 'Carries_PrgC', 'Carries_1/3', 'Carries_CPA', 'Carries_Mis', 'Carries_Dis', 'Receiving_Rec', 'Receiving_PrgR', 'Performance_CrdY', 'Performance_CrdR', 'Performance_2CrdY', 'Performance_Fls', 'Performance_Fld', 'Performance_Off', 'Performance_Crs', 'Performance_Int', 'Performance_TklW', 'Performance_PKwon', 'Performance_PKcon', 'Performance_OG', 'Performance_Recov', 'Aerial Duels_Won', 'Aerial Duels_Lost', 'Aerial Duels_Won%', 'Age_', 'Playing Time_MP', 'Playing Time_Min', 'Playing Time_Mn/MP', 'Playing Time_Min%', 'Playing Time_90s', 'Starts_Starts', 'Starts_Mn/Start', 'Starts_Compl', 'Subs_Subs', 'Subs_Mn/Sub', 'Subs_unSub', 'Team Success_PPM', 'Team Success_onG', 'Team Success_onGA', 'Team Success_+/-', 'Team Success_+/-90', 'Team Success (xG)_onxG', 'Team Success (xG)_onxGA', 'Team Success (xG)_xG+/-', 'Team Success (xG)_xG+/-90', 'Playing Time_Starts', 'Performance_GA', 'Performance_GA90', 'Performance_SoTA', 'Performance_Saves', 'Performance_Save%', 'Performance_W', 'Performance_D', 'Performance_L', 'Performance_CS', 'Performance_CS%', 'Penalty Kicks_PKatt', 'Penalty Kicks_PKA', 'Penalty Kicks_PKsv', 'Penalty Kicks_PKm', 'Penalty Kicks_Save%', 'Goals_GA', 'Goals_PKA', 'Goals_FK', 'Goals_CK', 'Goals_OG', 'Expected_PSxG', 'Expected_PSxG/SoT', 'Expected_PSxG+/-', 'Expected_/90', 'Launched_Cmp', 'Launched_Att', 'Launched_Cmp%', 'Passes_Att (GK)', 'Passes_Thr', 'Passes_Launch%', 'Passes_AvgLen', 'Goal Kicks_Att', 'Goal Kicks_Launch%', 'Goal Kicks_AvgLen', 'Crosses_Opp', 'Crosses_Stp', 'Crosses_Stp%', 'Sweeper_#OPA', 'Sweeper_#OPA/90', 'Sweeper_AvgDist']

# %%
df = df[df['Playing Time_Min'] >= 900]
df['Eficiência'] = df["Tackles_TklW"] / df["Tackles_Tkl"]
df['Eficiência'] = df['Eficiência'].fillna(0)

df["IEDO"] = (df["SCA Types_Def"] + df["SCA Types_Def"] + df["Tackles_Att 3rd"]) * df['Eficiência']
df['Eficiência']
# Ordenar pela nova métrica em ordem decrescente
df = df.sort_values(by='IEDO', ascending=False)
df.index = range(1, len(df) + 1)
df.head(10)
# Out:
#     Unnamed: 0             league_  season_           team_  players_used_  \
# 1            2  ENG-Premier League     2425     Bournemouth             28
# 2            0  ENG-Premier League     2425         Arsenal             24
# 3           13  ENG-Premier League     2425  Manchester Utd             27
# 4            3  ENG-Premier League     2425       Brentford             27
# 5           14  ENG-Premier League     2425   Newcastle Utd             24
# 6           17  ENG-Premier League     2425       Tottenham             31
# 7           11  ENG-Premier League     2425       Liverpool             24
# 8            5  ENG-Premier League     2425         Chelsea             27
# 9            4  ENG-Premier League     2425        Brighton             30
# 10           7  ENG-Premier League     2425         Everton             25
#
#     90s_  Standard_Gls  Standard_Sh  Standard_SoT  Standard_SoT%  ...  \
# 1     25            44          396           138           34.8  ...
# 2     25            49          338           122           36.1  ...
# 3     25            27          332           108           32.5  ...
# 4     25            43          285           118           41.4  ...
# 5     25            41          339           107           31.6  ...
# 6     25            46          367           132           36.0  ...
# 7     26            62          437           159           36.4  ...
# 8     25            46          397           133           33.5  ...
# 9     25            37          348           114           32.8  ...
# 10    25            24          274            87           31.8  ...
#
#     Goal Kicks_Launch%  Goal Kicks_AvgLen  Crosses_Opp  Crosses_Stp  \
# 1                 54.7               42.6          323           16
# 2                 57.0               42.3          271           35
# 3                 40.3               32.1          276           16
# 4                 44.6               37.4          412           32
# 5                 55.2               43.2          345           31
# 6                  4.7               15.4          335           31
# 7                 23.4               24.7          254           10
# 8                 14.8               19.1          248           31
# 9                 26.5               24.7          293           21
# 10                54.8               44.4          366           21
#
#     Crosses_Stp%  Sweeper_#OPA  Sweeper_#OPA/90  Sweeper_AvgDist  Eficiência  \
# 1            5.0            38             1.52             15.6    0.586279
# 2           12.9            38             1.52             15.9    0.603365
# 3            5.8            17             0.68             11.6    0.600753
# 4            7.8            26             1.04             11.8    0.612293
# 5            9.0            42             1.68             15.3    0.623762
# 6            9.3            29             1.16             11.1    0.643805
# 7            3.9            40             1.54             15.2    0.618182
# 8           12.5            47             1.88             15.3    0.622449
# 9            7.2            39             1.56             15.4    0.598194
# 10           5.7            50             2.00             16.2    0.576846
#
#          IEDO
# 1   62.145530
# 2   61.543269
# 3   59.474576
# 4   58.780142
# 5   56.762376
# 6   56.654867
# 7   56.254545
# 8   54.775510
# 9   54.435666
# 10  51.339321
#
# [10 rows x 197 columns]

# %%
df_filtro = df[["team_","season_","Tackles_Tkl","Tackles_TklW","Tackles_Att 3rd","SCA Types_Def", "GCA Types_Def","Eficiência", "IEDO"]] 
df_filtro.head(10)
# Out:
#              team_  season_  Tackles_Tkl  Tackles_TklW  Tackles_Att 3rd  \
# 1      Bournemouth     2425          481           282               70
# 2          Arsenal     2425          416           251               86
# 3   Manchester Utd     2425          531           319               79
# 4        Brentford     2425          423           259               78
# 5    Newcastle Utd     2425          404           252               63
# 6        Tottenham     2425          452           291               74
# 7        Liverpool     2425          440           272               65
# 8          Chelsea     2425          392           244               56
# 9         Brighton     2425          443           265               73
# 10         Everton     2425          501           289               71
#
#     SCA Types_Def  GCA Types_Def  Eficiência       IEDO
# 1              18              1    0.586279  62.145530
# 2               8              1    0.603365  61.543269
# 3              10              4    0.600753  59.474576
# 4               9              1    0.612293  58.780142
# 5              14              1    0.623762  56.762376
# 6               7              1    0.643805  56.654867
# 7              13              0    0.618182  56.254545
# 8              16              2    0.622449  54.775510
# 9               9              1    0.598194  54.435666
# 10              9              3    0.576846  51.339321

# %%
df_filtro["Eficiência"] = df_filtro.get("Eficiência", 0).round(2)
df_filtro["IEDO"] = df_filtro.get("IEDO", 0).round(2)
df_filtro.head()
# Out:
# [03/23/25 18:02:47] WARNING  C:\Users\luizf\AppData\Local\Temp\ipykernel_10552\3997877141.py:1:     ]8;id=206886;file://c:\Users\luizf\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=558232;file://c:\Users\luizf\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              SettingWithCopyWarning:
#                              A value is trying to be set on a copy of a slice from a DataFrame.
#                              Try using .loc = value instead
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_filtro["Eficiência"] = df_filtro.get("Eficiência", 0).round(2)
#                     WARNING  C:\Users\luizf\AppData\Local\Temp\ipykernel_10552\3997877141.py:2:     ]8;id=811322;file://c:\Users\luizf\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=598262;file://c:\Users\luizf\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              SettingWithCopyWarning:
#                              A value is trying to be set on a copy of a slice from a DataFrame.
#                              Try using .loc = value instead
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_filtro["IEDO"] = df_filtro.get("IEDO", 0).round(2)
#             team_  season_  Tackles_Tkl  Tackles_TklW  Tackles_Att 3rd  \
# 1     Bournemouth     2425          481           282               70
# 2         Arsenal     2425          416           251               86
# 3  Manchester Utd     2425          531           319               79
# 4       Brentford     2425          423           259               78
# 5   Newcastle Utd     2425          404           252               63
#
#    SCA Types_Def  GCA Types_Def  Eficiência   IEDO
# 1             18              1        0.59  62.15
# 2              8              1        0.60  61.54
# 3             10              4        0.60  59.47
# 4              9              1        0.61  58.78
# 5             14              1        0.62  56.76

# %%
df_filtro.rename(columns={
    "team_": "Time",
    "season_": "Temporada",
    "Tackles_Tkl": "Desarmes",
    "Tackles_TklW": "Desarmes Ganhos",
    "Tackles_Att 3rd": "Desarmes no Terço Final",
    "SCA Types_Def": "SCA DEF",
    "GCA Types_Def": "GCA DEF"
}, inplace=True)
df_filtro.to_csv("FILTROIEDO_"+ csvnome)
df_filtro.head(10)
# Out:
#                     WARNING  C:\Users\luizf\AppData\Local\Temp\ipykernel_10552\2469721815.py:1:     ]8;id=517365;file://c:\Users\luizf\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=319920;file://c:\Users\luizf\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              SettingWithCopyWarning:
#                              A value is trying to be set on a copy of a slice from a DataFrame
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_filtro.rename(columns={
#               Time  Temporada  Desarmes  Desarmes Ganhos  \
# 1      Bournemouth       2425       481              282
# 2          Arsenal       2425       416              251
# 3   Manchester Utd       2425       531              319
# 4        Brentford       2425       423              259
# 5    Newcastle Utd       2425       404              252
# 6        Tottenham       2425       452              291
# 7        Liverpool       2425       440              272
# 8          Chelsea       2425       392              244
# 9         Brighton       2425       443              265
# 10         Everton       2425       501              289
#
#     Desarmes no Terço Final  SCA DEF  GCA DEF  Eficiência   IEDO
# 1                        70       18        1        0.59  62.15
# 2                        86        8        1        0.60  61.54
# 3                        79       10        4        0.60  59.47
# 4                        78        9        1        0.61  58.78
# 5                        63       14        1        0.62  56.76
# 6                        74        7        1        0.64  56.65
# 7                        65       13        0        0.62  56.25
# 8                        56       16        2        0.62  54.78
# 9                        73        9        1        0.60  54.44
# 10                       71        9        3        0.58  51.34
